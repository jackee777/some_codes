# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.arange(-2, 2, 0.01)

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))
tanh = lambda x: 2 * sigmoid(2*x) - 1
relu = lambda x: np.max(np.vstack([x, np.zeros(x.shape)]), axis=0)
leakly =lambda x: np.max(np.vstack([x, x*0.01]), axis=0)
step = lambda x: np.array(x > 0, dtype = np.int)

# %%
plt.figure(figsize=(16/2,9/2))
plt.plot(x, sigmoid(x), label="sigmoid")
plt.plot(x, tanh(x), label="tanh")
plt.plot(x, relu(x), label="relu")
#plt.plot(x, leakly(x), label="leakly")
plt.legend(loc="upper left")

# %%
x = np.arange(-6, 6, 0.01)

# %%
plt.figure(figsize=(16/2,9/2))
plt.plot(x, sigmoid(x), label="sigmoid")
plt.plot(x, step(x), label="step")
plt.tick_params(labelsize=24)
#plt.plot(x, leakly(x), label="leakly")
plt.ylim(-0.2, 1.2)
plt.legend(loc="upper left", fontsize=24)
